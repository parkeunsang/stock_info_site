# %% [markdown]
# # 종목토론실
# 네이버 종목토론실 데이터 수집

# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd

# %%
url = f'https://finance.naver.com/item/board.nhn?code={code}&page={page}'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
code = '005930'
page = 2

# %%
result = requests.get(url, headers = headers)

# %%
soup = BeautifulSoup(result.text)

# %%
tbody = soup.find('tbody')

# %%
ths = [x.text for x in trs[0].find_all('th')]

# %%
trs = tbody.find_all('tr')
table = []
for tr in trs[2:]:
    row = [x.text.strip() for x in tr.find_all('td')]
    if len(row) > 1:  # 5번째 줄마다 value가 안들어있음
        table.append(row)

# %%
pd.DataFrame(table)
# Out:
#                    0                                       1         2    3  \
# 0   2021.07.12 23:26               개인들이 기관 외인들이 파는 하루 700...  get6****   61
# 1   2021.07.12 23:25                       대통령후보도  눈치 껏 해라..  budd****   46
# 2   2021.07.12 23:25                       무능과방관으로 남탓만하는 이정부  woos****   45
# 3   2021.07.12 23:22               너희들 오늘 ///////////////...  cpff****  200
# 4   2021.07.12 23:18                         내일장은 만만치 않을듯...  mein****  153
# 5   2021.07.12 23:18             왜구당 난리난 이유 알려줘\n\t\t\t\t[1]  hshj****  131
# 6   2021.07.12 23:18                                 OOO 네이버  jhc0****  113
# 7   2021.07.12 23:17               새누리당김진태전의원= 윤석열은 기업인과 ...  tjdr****  123
# 8   2021.07.12 23:17               석열 따라잡기  /////////////...  cpff****  100
# 9   2021.07.12 23:14               원래 위험이 커야 이익도 크고,위험이 낮...  get6****  138
# 10  2021.07.12 23:12      검사 사칭.음주운전.시민폭행 전과 4범\n\t\t\t\t[1]  seou****  150
# 11  2021.07.12 23:12     뭉가 이놈 진짜 미     친놈 아니냐?\n\t\t\t\t[4]  dbxb****  150
# 12  2021.07.12 23:12  때릴수록 크지는것은 ?//////////...\n\t\t\t\t[2]  cpff****  147
# 13  2021.07.12 23:12                     이때까지 꾸준히 수익 줘서 고마웠다  sjhc****  124
# 14  2021.07.12 23:11               미국주식 보니깐..스포츠용품도 대단하군....  zeus****  109
# 15  2021.07.12 23:09             남탓하기 좋아하는 무능정부\n\t\t\t\t[1]  wrkc****  109
# 16  2021.07.12 23:08               Nasdaq daw s&p 신고가 행진....  red_****   99
# 17  2021.07.12 23:08                        이주식\n\t\t\t\t[2]  na13****  157
# 18  2021.07.12 23:07                               문정부 참 무능해  wrkc****   86
# 19  2021.07.12 23:06                             차라리 정치글을 써라  sjs3****   61
#
#      4  5
# 0    1  1
# 1    1  0
# 2    1  1
# 3    0  0
# 4    1  0
# 5    1  1
# 6    0  0
# 7    2  3
# 8    0  1
# 9    0  1
# 10  13  4
# 11   9  4
# 12   0  1
# 13   2  1
# 14   1  1
# 15   3  2
# 16   0  2
# 17   0  1
# 18   4  2
# 19   1  0
